# %% [markdown]
# # Print()

# %%
print(10)
# Out:
# 10

# %%
print(10,4)
print(10,'python')
# Out:
# 10 4
# 10 python

# %% [markdown]
# # imp

# %%
num1 = 20
num2 = 30
add = num1+num2
print('The addition of',num1,'add',num2,'is=',add)
# Out:
# The addition of 20 add 30 is= 50

# %%
name = 'python'
age = 20
city = 'hyderbad city'

print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is python and i am 20 years old form hyderbad city

# %% [markdown]
# # print() with format method

# %%
num1 = 20
num2 = 50

add = num1+num2

print('The addition of{} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of20 and 50 is= 70

# %%
a = 1
b = 2

c = a+b

print('addition of {} and {} is={}'.format(a,b,c))
# Out:
# addition of 1 and 2 is=3

# %% [markdown]
# # f

# %%
num1 = 23
num2 = 25

add = num1+num2
print(f'The addition of {num1} and {num2} is={add}')
# Out:
# The addition of 23 and 25 is=48

# %%
num1 = 20
num2 = 89

add = num1 + num2

print(f'The addition of {num1} and {num2} is ={add}')
# Out:
# The addition of 20 and 89 is =109

# %%
print('hello','hai','how are you', sep = '--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep = '****')
# Out:
# hello****hai****how are you

# %% [markdown]
# # operator

# %%
x = 2

# %%
x += 4

# %%
x
# Out:
# 6

# %%
x +=2

# %%
x
# Out:
# 8

# %%
x *= 2

# %%
x
# Out:
# 16

# %%
x -= 2

# %%
x
# Out:
# 14

# %%
x/2=4
# Out:
#   Cell In[25], line 1
#     x/2=4
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a < 8 and b < 5
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
x = False

# %%
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
y = True

# %%
y
# Out:
# True

# %%
not y
# Out:
# False
