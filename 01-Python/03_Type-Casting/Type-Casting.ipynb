# %% [markdown]
# ### float,string,bool,complex  ->  int

# %%
int(50.34) # we can convert float to int
# Out:
# 50

# %%
int(True) # boolean to int possible
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j) #complex to int is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10') #number string is possible
# Out:
# 10

# %%
int('ten') #charecter string is not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # in type casting while typecast from all other datatype to int is possible except complex and text string

# %% [markdown]
# # int,string,bool,complex -> float

# %%
float(110)
# Out:
# 110.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float(false)
#
# NameError: name 'false' is not defined

# %%
float(1+5j) #complex is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float(1+5j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10') #number string
# Out:
# 10.0

# %%
float('ten') #text string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # int,string,float,complex -> bool

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(-3)
# Out:
# True

# %% [markdown]
# # int,string,float,bool -> complex

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(3,4)
# Out:
# (3+4j)

# %%
complex(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 complex(3,4,5)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('10','11')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 complex('10','11')
#
# TypeError: complex() can't take second arg if first is a string

# %%
str(10)
# Out:
# '10'

# %%
str(10.4)
# Out:
# '10.4'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'
