# %% [markdown]
# ### Swapping

# %% [markdown]
# ### 1. Using a temp or third variable

# %%
a = 10
b = 20

# %%
temp = a
a = b
b = temp

# %%
a
# Out:
# 20

# %%
b
# Out:
# 10

# %% [markdown]
# ### 2. Using arithmetic operator

# %%
c = 10
d = 40

# %%
c = c + d
d = c - d
c = c - d

# %%
c
# Out:
# 40

# %%
d
# Out:
# 10

# %% [markdown]
# ### 3. Using miltiple assignment

# %%
e = 10 
f = 101

# %%
e, f = f, e

# %%
e
# Out:
# 101

# %%
f
# Out:
# 10

# %% [markdown]
# ### Common Mistake

# %%
a1 = 20
a2 = 60

# %%
a = b
b = a

# %%
a
# Out:
# 10

# %%
b
# Out:
# 10
