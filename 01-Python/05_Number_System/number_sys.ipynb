# %% [markdown]
# # we convert number to binary number system

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25) # number to octal number system
# Out:
# '0o31'

# %%
int(0o31) # octal to number
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %%
int(0x9)
# Out:
# 9

# %%
int(0*6)
# Out:
# 0

# %%
int(0x5)
# Out:
# 5
