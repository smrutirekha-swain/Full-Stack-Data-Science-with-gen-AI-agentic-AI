# %% [markdown]
# String

# %%
name = "Rekha"

# %%
name
# Out:
# 'Rekha'

# %%
name.upper()
# Out:
# 'REKHA'

# %%
name.endswith("ry")
# Out:
# False

# %%
name.endswith("jerry")
# Out:
# False

# %%
name.lower()
# Out:
# 'rekha'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("r")
# Out:
# 0

# %%
s = "CodeWithRekha"
print(len(s))  # Output: 13
# Out:
# 13

# %% [markdown]
# Slicing

# %%
s[0:5]
# Out:
# 'CodeW'

# %%
s[1:-1]
# Out:
# 'odeWithRekh'

# %%
s[1:12]
# Out:
# 'odeWithRekh'

# %%
s[-12:-1]
# Out:
# 'odeWithRekh'

# %%
s[1:12]
# Out:
# 'odeWithRekh'

# %%
r = 'String slicing is used to extract a specific part of a string using index positions.
It is written as string[start:end] and returns the characters between the given positions.'
# Out:
#   Cell In[45], line 1
#     r = 'String slicing is used to extract a specific part of a string using index positions.
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
r = "String slicing is used to extract a specific part of a string using index positions.
It is written as string[start:end] and returns the characters between the given positions."
# Out:
#   Cell In[29], line 1
#     r = "String slicing is used to extract a specific part of a string using index positions.
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
r = ''''String slicing is used to extract a specific part of a string using index positions.
It is written as string[start:end] and returns the characters between the given positions.'''

# %%
# If you want to print multiple lines, you can use triple quotes (''' or """) to write and display text on more than one line.
