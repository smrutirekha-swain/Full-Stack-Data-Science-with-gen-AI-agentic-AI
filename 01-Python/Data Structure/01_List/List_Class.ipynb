# %% [markdown]
# ### List

# %% [raw]
# In Python, a list is an ordered, mutable (changeable) collection that can store multiple items of different data types.

# %% [markdown]
# ### Creating a List

# %%
# Empty list
my_list = []

# List with elements
numbers = [1, 2, 3, 4, 5]

# Mixed data types
mixed = [10, "Python", 3.14, True]

# %%
l = [] #empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20,30,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l.append(20,30,40)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
l1 = [10, 3.5, True, 1+2j, 'welcome']
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1.append([1,2,3]) # nested list 
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# True

# %%
id(l) != id(l3)
# Out:
# False

# %%
print(id(l))
print(id(l3))
# Out:
# 2325133249088
# 2325133249088

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# []
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# []

# %%
print(l)
print(l1)
# Out:
# []
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l.count(10)
# Out:
# 0

# %%
print(l)
# Out:
# []

# %%
l.extend(l1) 
l
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
a1 = [1,2,3]
b1 = [4,5,6]

# %%
a1.extend(b1)
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1.index(10)
# Out:
# 0

# %%
l1[:]
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[4]
# Out:
# 'welcome'

# %%
l1[:3]
# Out:
# [10, 3.5, True]

# %%
l1[3:]
# Out:
# [(1+2j), 'welcome', [1, 2, 3]]

# %%
l1[0:5:2]
# Out:
# [10, True, 'welcome']

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[-3]
# Out:
# (1+2j)

# %%
l1[::-1]
# Out:
# [[1, 2, 3], 'welcome', (1+2j), True, 3.5, 10]

# %%
l1[::-2]
# Out:
# [[1, 2, 3], (1+2j), 3.5]

# %%
print(l1[4][0])
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
print(l1[4][5])
print(l1[4][6])
print(l1[4][7])
# Out:
# w
# e
# l
# c
# o
# m
# e
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 8
#       6 print(l1[4][5])
#       7 print(l1[4][6])
# ----> 8 print(l1[4][7])
#
# IndexError: string index out of range

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[0] = 100

# %%
l1
# Out:
# [100, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1.
# Out:
#   Cell In[59], line 1
#     l1.
#        ^
# SyntaxError: invalid syntax
